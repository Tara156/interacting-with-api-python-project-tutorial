# %% [markdown]
# ## Api de spotify, importar librerias y datos para autenticación

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv  # para tomar credenciales del .env

# load the .env file variables
load_dotenv()

client_id= os.environ.get("client_id")
client_secret= os.environ.get("client_secret")

# %% [markdown]
# ## Autenticación automática con el SpotifyClientCredentials de spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Es el uri Identificador interno de spotify, internamente lo convierte a url
lz_uri = 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'

#clase que gestiona el token de acceso, se crea una instancia de esa clase ya autenticado
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id,client_secret=client_secret))

# %% [markdown]
# ## Consumir el api de spotify mediante uri

# %% [markdown]
# ## info del artista
#
#     metodo spotift.artist

# %%
inf_artist = spotify.artist(lz_uri)
inf_artist
type(inf_artist)
print(inf_artist.keys())
print(list(inf_artist.keys()))
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])
# ['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri']

# %%
inf_artist
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#  'followers': {'href': None, 'total': 5355027},
#  'genres': ['latin pop', 'colombian pop', 'rock en español'],
#  'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#  'id': '0UWZUmn7sybxMCqrw9tGa7',
#  'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb1aefa2dd52fde10eba9b4d5d',
#    'height': 640,
#    'width': 640},
#   {'url': 'https://i.scdn.co/image/ab676161000051741aefa2dd52fde10eba9b4d5d',
#    'height': 320,
#    'width': 320},
#   {'url': 'https://i.scdn.co/image/ab6761610000f1781aefa2dd52fde10eba9b4d5d',
#    'height': 160,
#    'width': 160}],
#  'name': 'Juanes',
#  'popularity': 77,
#  'type': 'artist',
#  'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}

# %% [markdown]
# ## Albumes del artista
#     Metodo: artist_albums

# %%
albumes_artista= spotify.artist_albums(lz_uri,limit=30)
albumes_artista
# Out:
# {'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7/albums?offset=0&limit=30&include_groups=album,single,compilation,appears_on',
#  'limit': 30,
#  'next': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7/albums?offset=30&limit=30&include_groups=album,single,compilation,appears_on',
#  'offset': 0,
#  'previous': None,
#  'total': 928,
#  'items': [{'album_type': 'album',
#    'total_tracks': 13,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/157buz5Int6IECXF2hKYak'},
#    'href': 'https://api.spotify.com/v1/albums/157buz5Int6IECXF2hKYak',
#    'id': '157buz5Int6IECXF2hKYak',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735b486e51d83f1d0aa0382f47',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e025b486e51d83f1d0aa0382f47',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048515b486e51d83f1d0aa0382f47',
#      'height': 64,
#      'width': 64}],
#    'name': 'Vida Cotidiana (Deluxe Version)',
#    'release_date': '2023-09-29',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:157buz5Int6IECXF2hKYak',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 11,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1fHpKy8dfAplGSfcOsqtOm'},
#    'href': 'https://api.spotify.com/v1/albums/1fHpKy8dfAplGSfcOsqtOm',
#    'id': '1fHpKy8dfAplGSfcOsqtOm',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2738db82e6ef0cf25bf2b9c9ff5',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e028db82e6ef0cf25bf2b9c9ff5',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048518db82e6ef0cf25bf2b9c9ff5',
#      'height': 64,
#      'width': 64}],
#    'name': 'Vida Cotidiana',
#    'release_date': '2023-05-19',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:1fHpKy8dfAplGSfcOsqtOm',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 12,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1u6LVowYLLPQVSS2o67YyW'},
#    'href': 'https://api.spotify.com/v1/albums/1u6LVowYLLPQVSS2o67YyW',
#    'id': '1u6LVowYLLPQVSS2o67YyW',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273849e0b8db07795283f4a832c',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02849e0b8db07795283f4a832c',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851849e0b8db07795283f4a832c',
#      'height': 64,
#      'width': 64}],
#    'name': 'Un Día Normal (20th Anniversary Remastered)',
#    'release_date': '2022-05-20',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:1u6LVowYLLPQVSS2o67YyW',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 12,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1pnliPS7mvHIMlBgwK7kgO'},
#    'href': 'https://api.spotify.com/v1/albums/1pnliPS7mvHIMlBgwK7kgO',
#    'id': '1pnliPS7mvHIMlBgwK7kgO',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273b879f11e2f16d95df017a023',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02b879f11e2f16d95df017a023',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851b879f11e2f16d95df017a023',
#      'height': 64,
#      'width': 64}],
#    'name': 'Origen',
#    'release_date': '2021-05-27',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:1pnliPS7mvHIMlBgwK7kgO',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 13,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2X45SzRfAFsxgkBxgryWfF'},
#    'href': 'https://api.spotify.com/v1/albums/2X45SzRfAFsxgkBxgryWfF',
#    'id': '2X45SzRfAFsxgkBxgryWfF',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2733cd4e2895e60808dc6d8249d',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e023cd4e2895e60808dc6d8249d',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048513cd4e2895e60808dc6d8249d',
#      'height': 64,
#      'width': 64}],
#    'name': 'Más Futuro Que Pasado',
#    'release_date': '2019-11-22',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:2X45SzRfAFsxgkBxgryWfF',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 12,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3nZrIskMQdaS5KWw45PIjd'},
#    'href': 'https://api.spotify.com/v1/albums/3nZrIskMQdaS5KWw45PIjd',
#    'id': '3nZrIskMQdaS5KWw45PIjd',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27362b1255019e7d3dd9c433994',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e0262b1255019e7d3dd9c433994',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d0000485162b1255019e7d3dd9c433994',
#      'height': 64,
#      'width': 64}],
#    'name': 'Mis Planes Son Amarte',
#    'release_date': '2017-05-12',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3nZrIskMQdaS5KWw45PIjd',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 15,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3htJFw3Ad4OaE30FbwO5nu'},
#    'href': 'https://api.spotify.com/v1/albums/3htJFw3Ad4OaE30FbwO5nu',
#    'id': '3htJFw3Ad4OaE30FbwO5nu',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739c47cc19b14dd2f7e68f44c9',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e029c47cc19b14dd2f7e68f44c9',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048519c47cc19b14dd2f7e68f44c9',
#      'height': 64,
#      'width': 64}],
#    'name': 'Loco De Amor (Tour Edition)',
#    'release_date': '2015-06-29',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3htJFw3Ad4OaE30FbwO5nu',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 11,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7bh3HOAz9lQmOEgDAXwy4v'},
#    'href': 'https://api.spotify.com/v1/albums/7bh3HOAz9lQmOEgDAXwy4v',
#    'id': '7bh3HOAz9lQmOEgDAXwy4v',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273a10d8e8d07d30d0c52ecebae',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02a10d8e8d07d30d0c52ecebae',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851a10d8e8d07d30d0c52ecebae',
#      'height': 64,
#      'width': 64}],
#    'name': 'Loco De Amor',
#    'release_date': '2014-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:7bh3HOAz9lQmOEgDAXwy4v',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 14,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'US',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'TN',
#     'LB',
#     'JO',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'TJ',
#     'VE',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6Zy2wrvOOW0sxTWy7nF9BH'},
#    'href': 'https://api.spotify.com/v1/albums/6Zy2wrvOOW0sxTWy7nF9BH',
#    'id': '6Zy2wrvOOW0sxTWy7nF9BH',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273bf486f515949760291fed7d3',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02bf486f515949760291fed7d3',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851bf486f515949760291fed7d3',
#      'height': 64,
#      'width': 64}],
#    'name': 'Tr3s Presents Juanes MTV Unplugged',
#    'release_date': '2012-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:6Zy2wrvOOW0sxTWy7nF9BH',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 10,
#    'available_markets': ['AR',
#     'BO',
#     'BR',
#     'CL',
#     'CO',
#     'CR',
#     'ES',
#     'GY',
#     'MX',
#     'PE',
#     'PY',
#     'SR',
#     'VE'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3YC801MC9LJZQeoMHyujAc'},
#    'href': 'https://api.spotify.com/v1/albums/3YC801MC9LJZQeoMHyujAc',
#    'id': '3YC801MC9LJZQeoMHyujAc',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27326b49708d430d06f7c8671b7',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e0226b49708d430d06f7c8671b7',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d0000485126b49708d430d06f7c8671b7',
#      'height': 64,
#      'width': 64}],
#    'name': 'P.A.R.C.E.',
#    'release_date': '2010-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3YC801MC9LJZQeoMHyujAc',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 13,
#    'available_markets': ['AE',
#     'AG',
#     'AR',
#     'AT',
#     'BA',
#     'BB',
#     'BG',
#     'BH',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'DE',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EG',
#     'ES',
#     'FJ',
#     'FR',
#     'GD',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IQ',
#     'IS',
#     'JM',
#     'JO',
#     'JP',
#     'KN',
#     'KR',
#     'KW',
#     'LB',
#     'LC',
#     'LK',
#     'LY',
#     'MA',
#     'ME',
#     'MK',
#     'MO',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RS',
#     'SA',
#     'SI',
#     'SR',
#     'SV',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'US',
#     'VC',
#     'VE',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5zl0FmMSVWelddFzNG5fBC'},
#    'href': 'https://api.spotify.com/v1/albums/5zl0FmMSVWelddFzNG5fBC',
#    'id': '5zl0FmMSVWelddFzNG5fBC',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739c70edaee6f9e1dcf58833fe',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e029c70edaee6f9e1dcf58833fe',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048519c70edaee6f9e1dcf58833fe',
#      'height': 64,
#      'width': 64}],
#    'name': 'P.A.R.C.E. (Deluxe Version)',
#    'release_date': '2010',
#    'release_date_precision': 'year',
#    'type': 'album',
#    'uri': 'spotify:album:5zl0FmMSVWelddFzNG5fBC',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 24,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'SC',
#     'KN',
#     'TT',
#     'AZ',
#     'KH',
#     'CM',
#     'TD',
#     'SZ',
#     'GN',
#     'KG',
#     'LA',
#     'MN',
#     'NP',
#     'RW',
#     'UZ',
#     'ZW',
#     'MU',
#     'MZ',
#     'CI',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3oYMEOpdQ3OeMCTSZoMcPQ'},
#    'href': 'https://api.spotify.com/v1/albums/3oYMEOpdQ3OeMCTSZoMcPQ',
#    'id': '3oYMEOpdQ3OeMCTSZoMcPQ',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273b0299fee6ad7ba3637581f00',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02b0299fee6ad7ba3637581f00',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851b0299fee6ad7ba3637581f00',
#      'height': 64,
#      'width': 64}],
#    'name': 'La Vida Es Un Ratico En Vivo',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3oYMEOpdQ3OeMCTSZoMcPQ',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 14,
#    'available_markets': ['AE',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MU',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TJ',
#     'TN',
#     'TR',
#     'TW',
#     'TZ',
#     'UA',
#     'US',
#     'VE',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0TFz2Xw2kzFlcYFGetcCMY'},
#    'href': 'https://api.spotify.com/v1/albums/0TFz2Xw2kzFlcYFGetcCMY',
#    'id': '0TFz2Xw2kzFlcYFGetcCMY',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2731a3925772178135aca2dec56',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e021a3925772178135aca2dec56',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048511a3925772178135aca2dec56',
#      'height': 64,
#      'width': 64}],
#    'name': 'La Vida Es Un Ratico',
#    'release_date': '2007-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:0TFz2Xw2kzFlcYFGetcCMY',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 7,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7aRsHh9qGaG0gyZz35W39c'},
#    'href': 'https://api.spotify.com/v1/albums/7aRsHh9qGaG0gyZz35W39c',
#    'id': '7aRsHh9qGaG0gyZz35W39c',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739e7910547d333b947580e048',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e029e7910547d333b947580e048',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048519e7910547d333b947580e048',
#      'height': 64,
#      'width': 64}],
#    'name': 'Íntimo - Live Sessions',
#    'release_date': '2005-05-10',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:7aRsHh9qGaG0gyZz35W39c',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 19,
#    'available_markets': ['AE',
#     'AG',
#     'AR',
#     'AT',
#     'BA',
#     'BB',
#     'BH',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'DE',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EG',
#     'ES',
#     'FJ',
#     'FR',
#     'GD',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IQ',
#     'IS',
#     'JM',
#     'JO',
#     'JP',
#     'KN',
#     'KR',
#     'KW',
#     'LB',
#     'LC',
#     'LK',
#     'LY',
#     'MA',
#     'ME',
#     'MK',
#     'MO',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RS',
#     'SA',
#     'SI',
#     'SR',
#     'SV',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'US',
#     'VC',
#     'VE',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0zjVfx8ez3fDVvUT5Z8kBE'},
#    'href': 'https://api.spotify.com/v1/albums/0zjVfx8ez3fDVvUT5Z8kBE',
#    'id': '0zjVfx8ez3fDVvUT5Z8kBE',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27329233dbf09716b46055127b7',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e0229233dbf09716b46055127b7',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d0000485129233dbf09716b46055127b7',
#      'height': 64,
#      'width': 64}],
#    'name': 'Mi Sangre 2005 Tour Edition',
#    'release_date': '2005-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:0zjVfx8ez3fDVvUT5Z8kBE',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 17,
#    'available_markets': ['AO',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BO',
#     'BR',
#     'BS',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CW',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'ET',
#     'FI',
#     'FR',
#     'GA',
#     'GB',
#     'GH',
#     'GM',
#     'GN',
#     'GR',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'IE',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LV',
#     'ME',
#     'MG',
#     'MK',
#     'MT',
#     'MU',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TD',
#     'TG',
#     'TH',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UG',
#     'VE',
#     'VN',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6XSSTHK08ICCZdS5AEq95R'},
#    'href': 'https://api.spotify.com/v1/albums/6XSSTHK08ICCZdS5AEq95R',
#    'id': '6XSSTHK08ICCZdS5AEq95R',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273ca8569284c726023968ca460',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02ca8569284c726023968ca460',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851ca8569284c726023968ca460',
#      'height': 64,
#      'width': 64}],
#    'name': 'Mi Sangre',
#    'release_date': '2004-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:6XSSTHK08ICCZdS5AEq95R',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'album',
#    'total_tracks': 12,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PT',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'ID',
#     'JP',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'HR',
#     'MK',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'JM',
#     'KI',
#     'LR',
#     'MW',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'AZ',
#     'BN',
#     'BI',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GN',
#     'KG',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'ZM',
#     'CD',
#     'CG',
#     'TJ',
#     'VE'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7IOugW3LC5qxTyceggg00d'},
#    'href': 'https://api.spotify.com/v1/albums/7IOugW3LC5qxTyceggg00d',
#    'id': '7IOugW3LC5qxTyceggg00d',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27329c76e25ad189e78fc769d2c',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e0229c76e25ad189e78fc769d2c',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d0000485129c76e25ad189e78fc769d2c',
#      'height': 64,
#      'width': 64}],
#    'name': 'Fijate Bien',
#    'release_date': '2000-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:7IOugW3LC5qxTyceggg00d',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'album'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5x3u3eFvoRgFP0Y65iOgw3'},
#    'href': 'https://api.spotify.com/v1/albums/5x3u3eFvoRgFP0Y65iOgw3',
#    'id': '5x3u3eFvoRgFP0Y65iOgw3',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273d6598337372ba08284f6a4e1',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02d6598337372ba08284f6a4e1',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851d6598337372ba08284f6a4e1',
#      'height': 64,
#      'width': 64}],
#    'name': 'Una Noche Contigo',
#    'release_date': '2025-04-25',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5x3u3eFvoRgFP0Y65iOgw3',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:2XwdwHP5q4aUn553Rcrp2H',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1nMJ6Cjyc6yTWoKToZoP6c'},
#    'href': 'https://api.spotify.com/v1/albums/1nMJ6Cjyc6yTWoKToZoP6c',
#    'id': '1nMJ6Cjyc6yTWoKToZoP6c',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f424fd9a3ec6e2e432c1fad3',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02f424fd9a3ec6e2e432c1fad3',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851f424fd9a3ec6e2e432c1fad3',
#      'height': 64,
#      'width': 64}],
#    'name': 'Las Mujeres',
#    'release_date': '2023-08-17',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:1nMJ6Cjyc6yTWoKToZoP6c',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vhNDa5ycK0ST968ek7kRr'},
#      'href': 'https://api.spotify.com/v1/artists/4vhNDa5ycK0ST968ek7kRr',
#      'id': '4vhNDa5ycK0ST968ek7kRr',
#      'name': 'Carlos Vives',
#      'type': 'artist',
#      'uri': 'spotify:artist:4vhNDa5ycK0ST968ek7kRr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3WfiftlzBXOAPkor0DdxeI'},
#    'href': 'https://api.spotify.com/v1/albums/3WfiftlzBXOAPkor0DdxeI',
#    'id': '3WfiftlzBXOAPkor0DdxeI',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27374877baa3f51833877172054',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e0274877baa3f51833877172054',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d0000485174877baa3f51833877172054',
#      'height': 64,
#      'width': 64}],
#    'name': 'Cecilia (feat. Juan Luis Guerra)',
#    'release_date': '2023-05-18',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3WfiftlzBXOAPkor0DdxeI',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nlpTZci9O5W8RsNoNH559'},
#      'href': 'https://api.spotify.com/v1/artists/3nlpTZci9O5W8RsNoNH559',
#      'id': '3nlpTZci9O5W8RsNoNH559',
#      'name': 'Juan Luis Guerra 4.40',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nlpTZci9O5W8RsNoNH559'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7bmsR2hl2kqvsHbP2c5OxC'},
#    'href': 'https://api.spotify.com/v1/albums/7bmsR2hl2kqvsHbP2c5OxC',
#    'id': '7bmsR2hl2kqvsHbP2c5OxC',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739c7e6731e7ca4517b59e9a8a',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e029c7e6731e7ca4517b59e9a8a',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d000048519c7e6731e7ca4517b59e9a8a',
#      'height': 64,
#      'width': 64}],
#    'name': 'Veneno',
#    'release_date': '2023-05-04',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:7bmsR2hl2kqvsHbP2c5OxC',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6WNr4SBLBhTqGWI17liKAb'},
#    'href': 'https://api.spotify.com/v1/albums/6WNr4SBLBhTqGWI17liKAb',
#    'id': '6WNr4SBLBhTqGWI17liKAb',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f5d82d313429421bd39b5ef2',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02f5d82d313429421bd39b5ef2',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851f5d82d313429421bd39b5ef2',
#      'height': 64,
#      'width': 64}],
#    'name': 'Ojalá',
#    'release_date': '2023-04-14',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:6WNr4SBLBhTqGWI17liKAb',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'},
#   {'album_type': 'single',
#    'total_tracks': 1,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4DNxSEEFQ0MdDb1vFZsdpG'},
#    'href': 'https://api.spotify.com/v1/albums/4DNxSEEFQ0MdDb1vFZsdpG',
#    'id': '4DNxSEEFQ0MdDb1vFZsdpG',
#    'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273ba15ed096d36a259a1304940',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616d00001e02ba15ed096d36a259a1304940',
#      'height': 300,
#      'width': 300},
#     {'url': 'https://i.scdn.co/image/ab67616d00004851ba15ed096d36a259a1304940',
#      'height': 64,
#      'width': 64}],
#    'name': 'Gris',
#    'release_date': '2023-03-03',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:4DNxSEEFQ0MdDb1vFZsdpG',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#      'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#      'id': '0UWZUmn7sybxMCqrw9tGa7',
#      'name': 'Juanes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#    'album_group': 'single'}]}

# %% [markdown]
# ## Llaves principales nivel general en la respuesta  del metodo albumes

# %%
type(albumes_artista)
print(albumes_artista.keys())
print(list(albumes_artista.keys()))
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])
# ['href', 'limit', 'next', 'offset', 'previous', 'total', 'items']

# %% [markdown]
# ## Llaves obtenidas de la llave principal items

# %%
print(albumes_artista['items'][0].keys())  
# dict_keys(['album_type', 'total_tracks', 'available_markets',
#  'external_urls', 'href', 'id', 'images', 'name', 'release_date',
#  'release_date_precision', 'type', 'uri', 'artists', 'album_group']
# Out:
# dict_keys(['album_type', 'total_tracks', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'type', 'uri', 'artists', 'album_group'])

# %% [markdown]
# ## Se imprime el id de cada albúm

# %%
for album  in albumes_artista['items']: 
    print("album :", album ['id'])
# Out:
# album : 157buz5Int6IECXF2hKYak
# album : 1fHpKy8dfAplGSfcOsqtOm
# album : 1u6LVowYLLPQVSS2o67YyW
# album : 1pnliPS7mvHIMlBgwK7kgO
# album : 2X45SzRfAFsxgkBxgryWfF
# album : 3nZrIskMQdaS5KWw45PIjd
# album : 3htJFw3Ad4OaE30FbwO5nu
# album : 7bh3HOAz9lQmOEgDAXwy4v
# album : 6Zy2wrvOOW0sxTWy7nF9BH
# album : 3YC801MC9LJZQeoMHyujAc
# album : 5zl0FmMSVWelddFzNG5fBC
# album : 3oYMEOpdQ3OeMCTSZoMcPQ
# album : 0TFz2Xw2kzFlcYFGetcCMY
# album : 7aRsHh9qGaG0gyZz35W39c
# album : 0zjVfx8ez3fDVvUT5Z8kBE
# album : 6XSSTHK08ICCZdS5AEq95R
# album : 7IOugW3LC5qxTyceggg00d
# album : 5x3u3eFvoRgFP0Y65iOgw3
# album : 0d7ZD04wdfBrPgnANTydiA
# album : 3h3ErEec09J09JoWPrTadq
# album : 1MWi7BMI9eTMb8a7RXNNHu
# album : 7yj8AlTezMYcITJprPkU9i
# album : 7K0rkFuaN2l85ZMNdnV9UB
# album : 6Pwm0aU0x9kKrt3doES2tc
# album : 2XwdwHP5q4aUn553Rcrp2H
# album : 1nMJ6Cjyc6yTWoKToZoP6c
# album : 3WfiftlzBXOAPkor0DdxeI
# album : 7bmsR2hl2kqvsHbP2c5OxC
# album : 6WNr4SBLBhTqGWI17liKAb
# album : 4DNxSEEFQ0MdDb1vFZsdpG

# %% [markdown]
# ## Se imprime el nombre de cada albúm

# %%
for album  in albumes_artista['items']:  
    print("album :", album ['name'])
# Out:
# album : Vida Cotidiana (Deluxe Version)
# album : Vida Cotidiana
# album : Un Día Normal (20th Anniversary Remastered)
# album : Origen
# album : Más Futuro Que Pasado
# album : Mis Planes Son Amarte
# album : Loco De Amor (Tour Edition)
# album : Loco De Amor
# album : Tr3s Presents Juanes MTV Unplugged
# album : P.A.R.C.E.
# album : P.A.R.C.E. (Deluxe Version)
# album : La Vida Es Un Ratico En Vivo
# album : La Vida Es Un Ratico
# album : Íntimo - Live Sessions
# album : Mi Sangre 2005 Tour Edition
# album : Mi Sangre
# album : Fijate Bien
# album : Una Noche Contigo
# album : El Pájaro Carpintero (Los Nuevos Canticuentos)
# album : Corazón de Imán (Homenaje a Medellín)
# album : El Chucu Chucu
# album : Pétalo de sal
# album : Niebla
# album : GALA Y DALÍ
# album : Nacimos Solos (Banda Sonora Original de la serie "Zorro")
# album : Las Mujeres
# album : Cecilia (feat. Juan Luis Guerra)
# album : Veneno
# album : Ojalá
# album : Gris

# %% [markdown]
# ## Para buscar las canciones del albúm por id de albúm
#         Metodo: album_tracks

# %%
canciones = spotify.album_tracks('7aRsHh9qGaG0gyZz35W39c')

# %% [markdown]
# ## Llaves principales nivel general en la respuesta  del metodo album_Tracks

# %%
type(canciones)
print(canciones.keys())
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# ## Llaves obtenidas de la llave princial items

# %%
print(canciones['items'][0].keys())
# Out:
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'name', 'preview_url', 'track_number', 'type', 'uri', 'is_local'])

# %% [markdown]
# ## Canciones por album

# %%
canciones_por_album = {}

for album in albumes_artista['items']:
    album_id = album['id']
    album_nombre = album['name']
    canciones = spotify.album_tracks(album_id)  #con el id obtenido del album para saber las canciones

    lista_canciones = []
    duration=[]

    for track in canciones['items']:
        lista_canciones.append(track['name'])
        duration.append(track['duration_ms'])

    canciones_por_album[album_nombre] = lista_canciones

# %%
# Mostrar resultados
for album, canciones in canciones_por_album.items():
    print(f"Álbum: {album}")
    for cancion in canciones:
        print(f"  - {cancion}")
    print()
# Out:
# Álbum: Vida Cotidiana (Deluxe Version)
#   - Mayo
#   - Veneno
#   - Más
#   - Canción Desaparecida (feat. Mabiland)
#   - Ojalá
#   - Cecilia (feat. Juan Luis Guerra 4.40)
#   - Gris
#   - Amores Prohibidos
#   - Vida Cotidiana
#   - El Abrazo
#   - Vuelo
#   - Semilla
#   - La Versión En Mi Cabeza
#
# Álbum: Vida Cotidiana
#   - Mayo
#   - Veneno
#   - Más
#   - Canción Desaparecida (feat. Mabiland)
#   - Ojalá
#   - Cecilia (feat. Juan Luis Guerra 4.40)
#   - Gris
#   - Amores Prohibidos
#   - Vida Cotidiana
#   - El Abrazo
#   - Vuelo
#
# Álbum: Un Día Normal (20th Anniversary Remastered)
#   - A Dios Le Pido - Remastered 2022
#   - Es Por Ti - Remastered 2022
#   - Un Día Normal - Remastered 2022
#   - La Paga - Remastered 2022
#   - La Única - Remastered 2022
#   - Luna - Remastered 2022
#   - Día Lejano - Remastered 2022
#   - Mala Gente - Remastered 2022
#   - Fotografía - Remastered 2022
#   - Desde Que Despierto Hasta Que Duermo - Remastered 2022
#   - La Historia De Juan - Remastered 2022
#   - La Noche - Remastered 2022
#
# Álbum: Origen
#   - Rebelión
#   - Volver
#   - Nuestro Juramento
#   - La Bilirrubina
#   - Todo Hombre Es Una Historia
#   - El Amor Después Del Amor
#   - Could You Be Loved
#   - Sin Medir Distancias
#   - No Tengo Dinero
#   - Dancing In The Dark
#   - De Oro
#   - Y Nos Dieron Las Diez
#
# Álbum: Más Futuro Que Pasado
#   - Aurora
#   - Tequila
#   - Ninguna
#   - Mala Manera
#   - Bonita
#   - El Pueblo
#   - Más Futuro Que Pasado
#   - Loco
#   - Mía Mía
#   - La Plata
#   - Pa Dentro
#   - Querer Mejor
#   - Querer Mejor - Spanglish Version
#
# Álbum: Mis Planes Son Amarte
#   - Perro Viejo
#   - Angel
#   - Fuego
#   - Alguna Vez
#   - El Ratico
#   - Hermosa Ingrata
#   - Bendecido
#   - Es Tarde
#   - Actitud
#   - Mis Planes Son Amarte
#   - Goodbye For Now
#   - Esto No Acaba
#
# Álbum: Loco De Amor (Tour Edition)
#   - Mil Pedazos
#   - Loco De Amor
#   - La Luz
#   - La Verdad
#   - Una Flor
#   - Delirio
#   - Laberinto
#   - Persiguiendo El Sol
#   - Corazón Invisible
#   - Me Enamoré De Ti
#   - Radio Elvis
#   - Juntos - From "McFarland, USA"/Soundtrack Version
#   - La Luz - Miami/2014
#   - Es Por Tí - Miami/2014
#   - Mil Pedazos - Miami/2014
#
# Álbum: Loco De Amor
#   - Mil Pedazos
#   - Loco De Amor
#   - La Luz
#   - La Verdad
#   - Una Flor
#   - Delirio
#   - Laberinto
#   - Persiguiendo El Sol
#   - Corazón Invisible
#   - Me Enamoré De Ti
#   - Radio Elvis
#
# Álbum: Tr3s Presents Juanes MTV Unplugged
#   - Fíjate Bien - MTV Unplugged
#   - La Paga - MTV Unplugged
#   - Nada Valgo Sin Tu Amor - MTV Unplugged
#   - Es Por Ti - MTV Unplugged
#   - Todo En Mi Vida Eres Tú - MTV Unplugged
#   - A Dios Le Pido - MTV Unplugged
#   - Hoy Me Voy - Live
#   - Volverte A Ver - MTV Unplugged
#   - La Camisa Negra - MTV Unplugged
#   - Azul Sabina - MTV Unplugged
#   - Para Tu Amor - MTV Unplugged
#   - La Señal - MTV Unplugged
#   - Me Enamora - MTV Unplugged
#   - Odio Por Amor - MTV Unplugged
#
# Álbum: P.A.R.C.E.
#   - Amigos
#   - Yerbatero
#   - La Soledad
#   - La Razón
#   - Segovia
#   - El Amor Lo Cura Todo
#   - Todos Los Días
#   - Y No Regresas
#   - Lo Nuestro
#   - Esta Noche
#
# Álbum: P.A.R.C.E. (Deluxe Version)
#   - Regalito 2.0
#   - Quimera
#   - Amigos
#   - Yerbatero
#   - La Soledad
#   - La Razón
#   - Segovia
#   - El Amor Lo Cura Todo
#   - Todos Los Días
#   - Y No Regresas
#   - Lo Nuestro
#   - Esta Noche
#   - Regalito
#
# Álbum: La Vida Es Un Ratico En Vivo
#   - Odio Por Amor
#   - Falsas Palabras
#   - No Creo En El Jamas
#   - Clase De Amor
#   - Me Enamora
#   - Hoy Me Voy
#   - La Vida Es Un Ratico
#   - Gotas De Agua Dulce
#   - La Mejor Parte De Mi
#   - Minas Piedras
#   - Tu Y Yo
#   - Bailala
#   - Difícil
#   - Tres
#   - Bandera De Manos
#   - Bandera De Manos
#   - Hoy Me Voy
#   - Clase De Amor - Live
#   - Bandera De Manos - Live
#   - Nada Valgo Sin Tu Amor - Live
#   - Me Enamora - Live At La Vida World Tour/2008
#   - Bailala - Live
#   - Hoy Me Voy - Live
#   - Rebelion - Live At La Vida World Tour/2008
#
# Álbum: La Vida Es Un Ratico
#   - No Creo En El Jamas
#   - Clase De Amor
#   - Me Enamora
#   - Hoy Me Voy
#   - La Vida Es Un Ratico
#   - Gotas De Agua Dulce
#   - La Mejor Parte De Mi
#   - Minas Piedras
#   - Tu Y Yo
#   - Bailala
#   - Difícil
#   - Tres
#   - Bandera De Manos
#   - Bandera De Manos
#
# Álbum: Íntimo - Live Sessions
#   - Es Por Tí - Live At Conway Studios
#   - La Única - Live At Conway Studios
#   - Nada Valgo Sin Tu Amor - Live At Conway Studios
#   - La Camisa Negra - Live At Conway Studios
#   - Mi Historia - Live At Conway Studios
#   - My History - Live At Conway Studios
#   - Los Cuentos Detrás De Las Canciones - Live At Conway Studios
#
# Álbum: Mi Sangre 2005 Tour Edition
#   - Ámame
#   - Para Tu Amor
#   - Sueños
#   - La Camisa Negra
#   - Nada Valgo Sin Tu Amor
#   - No Siento Penas
#   - Dámelo
#   - Lo Que Me Gusta A Mi
#   - Rosario Tijeras
#   - ¿Qué Pasa?
#   - Volverte A Ver
#   - Tu Guardián
#   - A Dios Le Pido - Live Mi Sangre Tour /2005
#   - La Camisa Negra - Live Mi Sangre Tour /2005
#   - Fotografía - Live Mi Sangre Tour /2005
#   - Nada Valgo Sin Tu Amor - Live Mi Sangre Tour /2005
#   - La Paga - Radio Version
#   - La Camisa Negra - Sonidero Nacional Remix
#   - Lo Que Importa
#
# Álbum: Mi Sangre
#   - Ámame
#   - Para Tu Amor
#   - Sueños
#   - La Camisa Negra
#   - Nada Valgo Sin Tu Amor
#   - No Siento Penas
#   - Dámelo
#   - Lo Que Me Gusta A Mi
#   - Rosario Tijeras
#   - ¿Qué Pasa?
#   - Volverte A Ver
#   - Tu Guardián
#   - A Dios Le Pido
#   - Es Por Tí
#   - Fotografía
#   - La Paga
#   - La Camisa Negra - Full Phatt Remix
#
# Álbum: Fijate Bien
#   - Ahi Le Va
#   - Para Ser Eterno
#   - Volcan
#   - Podemos Hacernos Daño
#   - Destino
#   - Nada
#   - Fijate Bien
#   - Vulnerable
#   - Soñador
#   - Ficcion
#   - Para Que
#   - Me Da Igual
#
# Álbum: Una Noche Contigo
#   - Una Noche Contigo
#
# Álbum: El Pájaro Carpintero (Los Nuevos Canticuentos)
#   - El Pájaro Carpintero - Los Nuevos Canticuentos
#
# Álbum: Corazón de Imán (Homenaje a Medellín)
#   - Corazón de Imán (Homenaje a Medellín)
#
# Álbum: El Chucu Chucu
#   - El Chucu Chucu
#
# Álbum: Pétalo de sal
#   - Pétalo de sal
#
# Álbum: Niebla
#   - Niebla
#
# Álbum: GALA Y DALÍ
#   - GALA Y DALÍ
#
# Álbum: Nacimos Solos (Banda Sonora Original de la serie "Zorro")
#   - Nacimos Solos - Banda Sonora Original de la serie "Zorro"
#
# Álbum: Las Mujeres
#   - Las Mujeres
#
# Álbum: Cecilia (feat. Juan Luis Guerra)
#   - Cecilia (feat. Juan Luis Guerra)
#
# Álbum: Veneno
#   - Veneno
#
# Álbum: Ojalá
#   - Ojalá
#
# Álbum: Gris
#   - Gris

# %% [markdown]
# ### Canciones_por album a diccionario

# %%
canciones_por_album # el diccionario

# %%
import pandas as pd

# Lista para ir acumulando filas
filas = []

# Convertir el dict en una lista de filas
filas = []
for album, canciones in canciones_por_album.items():
    for nombre in canciones:
        filas.append({
            "album": album,
            "nombre_cancion": nombre
        })

# Crear el DataFrame
df_canciones = pd.DataFrame(filas)

# %% [markdown]
# ## Obtenemos el dataframe uno que es llamado df_canciones que tiene album y cancion

# %% [markdown]
# ## Top tracks del artista
#     metodo artist_top_tracks

# %%
# top_tracks=spotify.artist_top_tracks(artist_uri, country='US')
top_tracks=spotify.artist_top_tracks(lz_uri, country='US')
top_tracks

# %% [markdown]
# ## Laves principales del metodo top_Tracks

# %%
print(top_tracks.keys())
print(list(top_tracks.keys()))
# Out:
# dict_keys(['tracks'])
# ['tracks']

# %% [markdown]
# top_tracks es un diccionario con una sola clave principal:
#
# 'tracks'y que contiene una lista de canciones, donde cada canción es un diccionario grande

# %%
first_track = top_tracks['tracks'][0]
print(first_track.keys())

# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms',
#            'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local',
#            'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# ## Para ver las claves de una clave

# %%
album_keys = top_tracks['tracks'][0]['album'].keys()
print(album_keys)

# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href',
#            'id', 'images', 'is_playable', 'name', 'release_date', 'release_date_precision',
#            'total_tracks', 'type', 'uri'])
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'is_playable', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
for track in top_tracks['tracks']:
    print("Track:", track['name'])  # nombre de la canción
    print("Álbum:", track['album']['name'])  # nombre del álbum
    print("Total de tracks:", track['album']['total_tracks']) # Total de tracks
    print(f"Duración: {track['duration_ms'] // 1000} segundos")
    print(f"Popularidad: {track['popularity']}")
    print("Artista principal:", track['artists'][0]['name'])  # nombre primer artista
    print("Link de Spotify:", track['external_urls']['spotify'])  # link canción
    print("-" * 30)
# Out:
# Track: Es Por Ti
# Álbum: Un Día Normal
# Total de tracks: 12
# Duración: 250 segundos
# Popularidad: 81
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/3b1IQflSLrgzYQPGFzI9cl
# ------------------------------
# Track: Besos En Guerra
# Álbum: Balas Perdidas
# Total de tracks: 12
# Duración: 231 segundos
# Popularidad: 80
# Artista principal: Morat
# Link de Spotify: https://open.spotify.com/track/1mlGScrDQqHqmhdIqE8MmA
# ------------------------------
# Track: 1-800-273-8255
# Álbum: Best Of 2017 Pop
# Total de tracks: 48
# Duración: 253 segundos
# Popularidad: 48
# Artista principal: Logic
# Link de Spotify: https://open.spotify.com/track/4v69JByq63AuhIa5ooNv7D
# ------------------------------
# Track: La Camisa Negra
# Álbum: Mi Sangre
# Total de tracks: 12
# Duración: 216 segundos
# Popularidad: 77
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/2EM9zpAc7PVeoAydmbfVIL
# ------------------------------
# Track: A Dios Le Pido
# Álbum: Un Día Normal
# Total de tracks: 12
# Duración: 205 segundos
# Popularidad: 76
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/129lYDVKnWtlJc2PZJviuA
# ------------------------------
# Track: Nada Valgo Sin Tu Amor
# Álbum: Mi Sangre
# Total de tracks: 12
# Duración: 196 segundos
# Popularidad: 75
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/6QdwofpqDvvNxX88C9A0iQ
# ------------------------------
# Track: Fotografía
# Álbum: Un Día Normal
# Total de tracks: 12
# Duración: 238 segundos
# Popularidad: 73
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/0dEPlb8waIqRtKpLb3l6So
# ------------------------------
# Track: Volverte A Ver
# Álbum: Mi Sangre
# Total de tracks: 12
# Duración: 217 segundos
# Popularidad: 72
# Artista principal: Juanes
# Link de Spotify: https://open.spotify.com/track/2ZqFfDwNjKvPu3USx3onhO
# ------------------------------
# Track: 506
# Álbum: SI AYER FUERA HOY
# Total de tracks: 12
# Duración: 180 segundos
# Popularidad: 71
# Artista principal: Morat
# Link de Spotify: https://open.spotify.com/track/4Q1oBLFPK9R4eUHkNlihlF
# ------------------------------
# Track: Y, ¿Si Fuera Ella? - + Es +
# Álbum: + Es + (El Concierto / En Directo En El Estadio Vicente Calderón / 2017)
# Total de tracks: 13
# Duración: 250 segundos
# Popularidad: 71
# Artista principal: Pablo Alborán
# Link de Spotify: https://open.spotify.com/track/114xlNyBqwTIkOdrU8LajN
# ------------------------------

# %%
# Función para buscar en diccionarios de diccionarios los valores que tiene internamente:
def explorar_claves(dic, nivel=0):
    if isinstance(dic, dict):
        for k, v in dic.items():
            print("  " * nivel + f"- {k}")
            explorar_claves(v, nivel + 1)
    elif isinstance(dic, list) and dic:
        print("  " * nivel + f"[Lista con {len(dic)} elementos]")
        explorar_claves(dic[0], nivel + 1)

explorar_claves(top_tracks)
# Out:
# - tracks
#   [Lista con 10 elementos]
#     - album
#       - album_type
#       - artists
#         [Lista con 1 elementos]
#           - external_urls
#             - spotify
#           - href
#           - id
#           - name
#           - type
#           - uri
#       - available_markets
#         [Lista con 92 elementos]
#       - external_urls
#         - spotify
#       - href
#       - id
#       - images
#         [Lista con 3 elementos]
#           - url
#           - height
#           - width
#       - is_playable
#       - name
#       - release_date
#       - release_date_precision
#       - total_tracks
#       - type
#       - uri
#     - artists
#       [Lista con 1 elementos]
#         - external_urls
#           - spotify
#         - href
#         - id
#         - name
#         - type
#         - uri
#     - available_markets
#       [Lista con 92 elementos]
#     - disc_number
#     - duration_ms
#     - explicit
#     - external_ids
#       - isrc
#     - external_urls
#       - spotify
#     - href
#     - id
#     - is_local
#     - is_playable
#     - name
#     - popularity
#     - preview_url
#     - track_number
#     - type
#     - uri

# %% [markdown]
# ## Top tracks a dataframe

# %%
import pandas as pd

# Lista donde almacenamos cada fila como diccionario
datos = []

for track in top_tracks['tracks']:
    fila = {
        "nombre_cancion": track['name'],
        "album": track['album']['name'],
        "total_tracks_album": track['album']['total_tracks'],
        "duracion_segundos": track['duration_ms'] // 1000,
        "popularidad": track['popularity'],
        "artista_principal": track['artists'][0]['name'],
        "link_spotify": track['external_urls']['spotify']
    }
    datos.append(fila)

# Crear el DataFrame
df_top_tracks = pd.DataFrame(datos)

# Mostrar las primeras filas
print(df_top_tracks.head())
# Out:
#     nombre_cancion             album  total_tracks_album  duracion_segundos  \
# 0        Es Por Ti     Un Día Normal                  12                250
# 1  Besos En Guerra    Balas Perdidas                  12                231
# 2   1-800-273-8255  Best Of 2017 Pop                  48                253
# 3  La Camisa Negra         Mi Sangre                  12                216
# 4   A Dios Le Pido     Un Día Normal                  12                205
#
#    popularidad artista_principal  \
# 0           81            Juanes
# 1           80             Morat
# 2           48             Logic
# 3           77            Juanes
# 4           76            Juanes
#
#                                         link_spotify
# 0  https://open.spotify.com/track/3b1IQflSLrgzYQP...
# 1  https://open.spotify.com/track/1mlGScrDQqHqmhd...
# 2  https://open.spotify.com/track/4v69JByq63AuhIa...
# 3  https://open.spotify.com/track/2EM9zpAc7PVeoAy...
# 4  https://open.spotify.com/track/129lYDVKnWtlJc2...

# %%
df_canciones.columns
# Out:
# Index(['album', 'nombre_cancion'], dtype='object')

# %% [markdown]
# ## Guarda los datos en una base de datos SQL.

# %% [markdown]
# Los dos dataframe que tenemos para guardar cada uno en una tabla son:
#
# df_canciones que tiene album y cancion ['album', 'nombre_cancion']
#
# df_top_tracks ['nombre_cancion', 'album', 'total_tracks_album', 'duracion_segundos', 'popularidad', 'artista_principal', 'link_spotify']

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# DATABASE_URL='postgresql://postgres:123@localhost:5432/SPOTIFY'
DATABASE_URL = 'postgresql+psycopg2://postgres:6991@localhost:5432/SPOTIFY'

# el engine de conexión
engine = create_engine(DATABASE_URL)

# %% [markdown]
# ## Guardar dataframes cono tablas

# %%
# Guardar df_canciones
df_canciones.to_sql("canciones_album", con=engine, if_exists="replace", index=False)

# Guardar df_top_tracks
df_top_tracks.to_sql("top_tracks", con=engine, if_exists="replace", index=False)
# Out:
# 10

# %% [markdown]
# ## se verifica guardado de tablas

# %%
SELECT * FROM canciones_album
SELECT * FROM top_tracks;

# %%
# Consultar la tabla canciones_album
df_canciones_consulta = pd.read_sql("SELECT * FROM canciones_album;", engine)
print(df_canciones_consulta.head())

# Consultar la tabla top_tracks
df_top_tracks_consulta = pd.read_sql("SELECT * FROM top_tracks;", engine)
print(df_top_tracks_consulta.head())
# Out:
#                              album                         nombre_cancion
# 0  Vida Cotidiana (Deluxe Version)                                   Mayo
# 1  Vida Cotidiana (Deluxe Version)                                 Veneno
# 2  Vida Cotidiana (Deluxe Version)                                    Más
# 3  Vida Cotidiana (Deluxe Version)  Canción Desaparecida (feat. Mabiland)
# 4  Vida Cotidiana (Deluxe Version)                                  Ojalá
#     nombre_cancion             album  total_tracks_album  duracion_segundos  \
# 0        Es Por Ti     Un Día Normal                  12                250
# 1  Besos En Guerra    Balas Perdidas                  12                231
# 2   1-800-273-8255  Best Of 2017 Pop                  48                253
# 3  La Camisa Negra         Mi Sangre                  12                216
# 4   A Dios Le Pido     Un Día Normal                  12                205
#
#    popularidad artista_principal  \
# 0           81            Juanes
# 1           80             Morat
# 2           48             Logic
# 3           77            Juanes
# 4           76            Juanes
#
#                                         link_spotify
# 0  https://open.spotify.com/track/3b1IQflSLrgzYQP...
# 1  https://open.spotify.com/track/1mlGScrDQqHqmhd...
# 2  https://open.spotify.com/track/4v69JByq63AuhIa...
# 3  https://open.spotify.com/track/2EM9zpAc7PVeoAy...
# 4  https://open.spotify.com/track/129lYDVKnWtlJc2...

# %%
df_canciones.to_sql(
    name='canciones_por_album',
    con=engine,
    if_exists='replace',  # O 'append' si quieres agregar sin borrar
    index=False  # No guardar el índice de pandas como columna
)
# Out:
# 242

# %% [markdown]
# ## Artistas similares

# %% [markdown]
# ##  Información de un album

# %% [markdown]
# # Autenticación manual, se debe obtener el token con mis credenciales. Consumo api de forma manual sin la libreria de spotity

# %%
import requests
import base64

client_id = '2c1b46ccc51349cea507d17de9e283b4'
client_secret = '7dab709ae99040d9aea2ca3f05803cd3'

# Codificar en base64
auth_str = f"{client_id}:{client_secret}"
b64_auth_str = base64.b64encode(auth_str.encode()).decode()

# Obtener token
token_url = "https://accounts.spotify.com/api/token"
headers = {
    "Authorization": f"Basic {b64_auth_str}",
    "Content-Type": "application/x-www-form-urlencoded"
}
data = {"grant_type": "client_credentials"}

response = requests.post(token_url, headers=headers, data=data)
access_token = response.json()['access_token']



artist_id = '0UWZUmn7sybxMCqrw9tGa7'  # Juanes
url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"

headers = {
    "Authorization": f"Bearer {access_token}"
}

# Especificar el país
params = {
    "country": "US"
}

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    top_tracks = response.json()
    for track in top_tracks['tracks']:
        print(f"🎵 {track['name']} — Popularidad: {track['popularity']}")
else:
    print("❌ Error:", response.status_code, response.text)

spotify.artist_top_tracks('0UWZUmn7sybxMCqrw9tGa7', country='US')
